# %%
from agents import Agent, Runner, trace
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
agent = Agent("jokester","You are a joke teller", model="gpt-4o-mini")

# %%
with trace:
    result = await Runner.run(agent, "Tell me a joke on AI agents")

# %%
print(result.final_output)
# Out:
# Why did the AI agent get kicked out of the party?
#
# Because it kept trying to optimize everyone's dance moves!
